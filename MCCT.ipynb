# %%
# !nvidia-smi
# Out:
# Wed Apr 13 01:38:34 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.89       Driver Version: 465.89       CUDA Version: 11.3     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# | 31%   44C    P0    30W / 130W |   6044MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1176    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      1440    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      1472    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A      4340      C   ...ab-1\anaconda3\python.exe    N/A      |
# |    0   N/A  N/A      6576      C   ...ab-1\anaconda3\python.exe    N/A      |
# |    0   N/A  N/A      6816    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A      7288    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      9372    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     10752    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A     11308    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A     13180    C+G   ...tifier\QMxNetworkSync.exe    N/A      |
# |    0   N/A  N/A     13424      C   ...ab-1\anaconda3\python.exe    N/A      |
# |    0   N/A  N/A     13688      C   ...ab-1\anaconda3\python.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
labels = ["COVID", "Lung_Opacity","Normal", "Viral Pneumonia"]
img_size = 32
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data(r'D:\Inam Ullah Khan\image1')
# Out:
# C:\Users\NLP-LA~1\AppData\Local\Temp/ipykernel_13688/1323174985.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(data)

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("COVID")
    elif(i[1] == 1):
          l.append("Lung_Opacity")
    elif(i[1] == 2):
          l.append("Normal")
    elif(i[1] == 3):
          l.append("Viral Pneumonia")
       
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# C:\Users\NLP-Lab-1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'COVID')

# %%
x_train = []
y_train = []


for feature, label in train:
  x_train.append(feature)
  y_train.append(label)
x_train = np.array(x_train) / 255
x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

# %%
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(x_train, y_train,
    test_size=0.15, stratify=y_train, random_state=42)

# %%
# !pip install -U -q tensorflow-addons

# %%
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np

# %%
y_train = keras.utils.to_categorical(
    y_train, num_classes=4, dtype='float32'
)
y_test = keras.utils.to_categorical(
    y_test, num_classes=4, dtype='float32'
)

# %%
positional_emb = True
conv_layers = 2
projection_dim = 128

num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
transformer_layers = 1
stochastic_depth_rate = 0.1

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 100
image_size = 32

# %%
num_classes = 4
input_shape = (32, 32, 3)

# %%
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (42177, 32, 32, 3) - y_train shape: (42177, 4)
# x_test shape: (7444, 32, 32, 3) - y_test shape: (7444, 4)

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super(CCTTokenizer, self).__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %%
# Referred from: github.com:rwightman/pytorch-image-models.
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super(StochasticDepth, self).__init__(**kwargs)
        self.drop_prob = drop_prop

    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (len(tf.shape(x)) - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
# Note the rescaling layer. These layers have pre-defined inference behavior.
data_augmentation = keras.Sequential(
    [
        layers.Rescaling(scale=1.0 / 255),
        layers.RandomCrop(image_size, image_size),
        layers.RandomFlip("horizontal"),
    ],
    name="data_augmentation",
)

# %%
def create_cct_model(
    image_size=image_size,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):

    inputs = layers.Input(input_shape)

    # Augment data.
    augmented = data_augmentation(inputs)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(augmented)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)

        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(num_classes)(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    model.summary()
    return model

# %%
def run_experiment(model):
    optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    name="Adam"
)

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(
            from_logits=True, label_smoothing=0.1
        ),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = r"D:\Inam Ullah Khan\models\test.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.10,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
    from sklearn.metrics import classification_report, confusion_matrix



    # as I've trained my model on MNIST as odd or even (binary classes)
    target_names = ["COVID", "Lung_Opacity","Normal", "Viral Pneumonia"]

    # get predict prob and label 
    ypred = model.predict(x_test, verbose=1)
    ypred = np.argmax(ypred, axis=1)
    print(classification_report(np.argmax(y_test, axis=1), ypred, target_names=target_names))
    import matplotlib.pyplot as plt
    import seaborn as sns
    import pandas as pd 

    cm = confusion_matrix(np.argmax(y_test, axis=1), ypred)
    cm = pd.DataFrame(cm, range(4),range(4))
    plt.figure(figsize = (10,10))

    sns.heatmap(cm, annot=True, annot_kws={"size": 12}) # font size
    plt.show()
    return history


cct_model = create_cct_model()
history = run_experiment(cct_model)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  data_augmentation (Sequential)  (None, 32, 32, 3)   0           ['input_3[0][0]']
#
#  cct_tokenizer_2 (CCTTokenizer)  (None, 64, 128)     75456       ['data_augmentation[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 64, 128)     0           ['cct_tokenizer_2[0][0]']
#  mbda)
#
#  layer_normalization_8 (LayerNo  (None, 64, 128)     256         ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 64, 128)     131968      ['layer_normalization_8[0][0]',
#  eadAttention)                                                    'layer_normalization_8[0][0]']
#
#  stochastic_depth_4 (Stochastic  (None, 64, 128)     0           ['multi_head_attention_2[0][0]']
#  Depth)
#
#  add_4 (Add)                    (None, 64, 128)      0           ['stochastic_depth_4[0][0]',
#                                                                   'tf.__operators__.add_2[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 64, 128)     256         ['add_4[0][0]']
#  ormalization)
#
#  dense_8 (Dense)                (None, 64, 128)      16512       ['layer_normalization_10[0][0]']
#
#  dropout_4 (Dropout)            (None, 64, 128)      0           ['dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 64, 128)      16512       ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 128)      0           ['dense_9[0][0]']
#
#  stochastic_depth_5 (Stochastic  (None, 64, 128)     0           ['dropout_5[0][0]']
#  Depth)
#
#  add_5 (Add)                    (None, 64, 128)      0           ['stochastic_depth_5[0][0]',
#                                                                   'add_4[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 64, 128)     256         ['add_5[0][0]']
#  ormalization)
#
#  dense_10 (Dense)               (None, 64, 1)        129         ['layer_normalization_11[0][0]']
#
#  tf.nn.softmax_2 (TFOpLambda)   (None, 64, 1)        0           ['dense_10[0][0]']
#
#  tf.linalg.matmul_2 (TFOpLambda  (None, 1, 128)      0           ['tf.nn.softmax_2[0][0]',
#  )                                                                'layer_normalization_11[0][0]']
#
#  tf.compat.v1.squeeze_2 (TFOpLa  (None, 128)         0           ['tf.linalg.matmul_2[0][0]']
#  mbda)
#
#  dense_11 (Dense)               (None, 4)            516         ['tf.compat.v1.squeeze_2[0][0]']
#
# ==================================================================================================
# Total params: 241,861
# Trainable params: 241,861
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 297/297 [==============================] - 13s 37ms/step - loss: 1.0995 - accuracy: 0.5519 - top-5-accuracy: 1.0000 - val_loss: 0.7989 - val_accuracy: 0.7459 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.7461 - accuracy: 0.7799 - top-5-accuracy: 1.0000 - val_loss: 0.6529 - val_accuracy: 0.8483 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.6482 - accuracy: 0.8407 - top-5-accuracy: 1.0000 - val_loss: 0.5971 - val_accuracy: 0.8743 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.6077 - accuracy: 0.8622 - top-5-accuracy: 1.0000 - val_loss: 0.5716 - val_accuracy: 0.8857 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.5765 - accuracy: 0.8812 - top-5-accuracy: 1.0000 - val_loss: 0.5631 - val_accuracy: 0.8900 - val_top-5-accuracy: 1.0000
# Epoch 6/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.5692 - accuracy: 0.8857 - top-5-accuracy: 1.0000 - val_loss: 0.5704 - val_accuracy: 0.8909 - val_top-5-accuracy: 1.0000
# Epoch 7/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.5561 - accuracy: 0.8932 - top-5-accuracy: 1.0000 - val_loss: 0.5495 - val_accuracy: 0.8992 - val_top-5-accuracy: 1.0000
# Epoch 8/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.5450 - accuracy: 0.8986 - top-5-accuracy: 1.0000 - val_loss: 0.5459 - val_accuracy: 0.9009 - val_top-5-accuracy: 1.0000
# Epoch 9/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.5341 - accuracy: 0.9047 - top-5-accuracy: 1.0000 - val_loss: 0.5333 - val_accuracy: 0.9078 - val_top-5-accuracy: 1.0000
# Epoch 10/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.5325 - accuracy: 0.9052 - top-5-accuracy: 1.0000 - val_loss: 0.5396 - val_accuracy: 0.9049 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.5195 - accuracy: 0.9127 - top-5-accuracy: 1.0000 - val_loss: 0.5301 - val_accuracy: 0.9097 - val_top-5-accuracy: 1.0000
# Epoch 12/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.5093 - accuracy: 0.9184 - top-5-accuracy: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.9196 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.5136 - accuracy: 0.9153 - top-5-accuracy: 1.0000 - val_loss: 0.5210 - val_accuracy: 0.9180 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4995 - accuracy: 0.9237 - top-5-accuracy: 1.0000 - val_loss: 0.5224 - val_accuracy: 0.9151 - val_top-5-accuracy: 1.0000
# Epoch 15/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4907 - accuracy: 0.9282 - top-5-accuracy: 1.0000 - val_loss: 0.5001 - val_accuracy: 0.9253 - val_top-5-accuracy: 1.0000
# Epoch 16/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4953 - accuracy: 0.9256 - top-5-accuracy: 1.0000 - val_loss: 0.4950 - val_accuracy: 0.9286 - val_top-5-accuracy: 1.0000
# Epoch 17/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4928 - accuracy: 0.9265 - top-5-accuracy: 1.0000 - val_loss: 0.5077 - val_accuracy: 0.9189 - val_top-5-accuracy: 1.0000
# Epoch 18/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4832 - accuracy: 0.9330 - top-5-accuracy: 1.0000 - val_loss: 0.5100 - val_accuracy: 0.9184 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4822 - accuracy: 0.9322 - top-5-accuracy: 1.0000 - val_loss: 0.4856 - val_accuracy: 0.9324 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4758 - accuracy: 0.9351 - top-5-accuracy: 1.0000 - val_loss: 0.4930 - val_accuracy: 0.9303 - val_top-5-accuracy: 1.0000
# Epoch 21/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4785 - accuracy: 0.9344 - top-5-accuracy: 1.0000 - val_loss: 0.5039 - val_accuracy: 0.9267 - val_top-5-accuracy: 1.0000
# Epoch 22/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4756 - accuracy: 0.9363 - top-5-accuracy: 1.0000 - val_loss: 0.4945 - val_accuracy: 0.9272 - val_top-5-accuracy: 1.0000
# Epoch 23/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4657 - accuracy: 0.9422 - top-5-accuracy: 1.0000 - val_loss: 0.4891 - val_accuracy: 0.9343 - val_top-5-accuracy: 1.0000
# Epoch 24/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4686 - accuracy: 0.9399 - top-5-accuracy: 1.0000 - val_loss: 0.5006 - val_accuracy: 0.9272 - val_top-5-accuracy: 1.0000
# Epoch 25/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4619 - accuracy: 0.9427 - top-5-accuracy: 1.0000 - val_loss: 0.5441 - val_accuracy: 0.9037 - val_top-5-accuracy: 1.0000
# Epoch 26/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4667 - accuracy: 0.9397 - top-5-accuracy: 1.0000 - val_loss: 0.4805 - val_accuracy: 0.9358 - val_top-5-accuracy: 1.0000
# Epoch 27/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4656 - accuracy: 0.9413 - top-5-accuracy: 1.0000 - val_loss: 0.4831 - val_accuracy: 0.9331 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4574 - accuracy: 0.9448 - top-5-accuracy: 1.0000 - val_loss: 0.4757 - val_accuracy: 0.9395 - val_top-5-accuracy: 1.0000
# Epoch 29/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4564 - accuracy: 0.9450 - top-5-accuracy: 1.0000 - val_loss: 0.4740 - val_accuracy: 0.9410 - val_top-5-accuracy: 1.0000
# Epoch 30/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4514 - accuracy: 0.9487 - top-5-accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.9381 - val_top-5-accuracy: 1.0000
# Epoch 31/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4558 - accuracy: 0.9460 - top-5-accuracy: 1.0000 - val_loss: 0.4751 - val_accuracy: 0.9393 - val_top-5-accuracy: 1.0000
# Epoch 32/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4520 - accuracy: 0.9477 - top-5-accuracy: 1.0000 - val_loss: 0.5100 - val_accuracy: 0.9201 - val_top-5-accuracy: 1.0000
# Epoch 33/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4465 - accuracy: 0.9517 - top-5-accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.9301 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4469 - accuracy: 0.9496 - top-5-accuracy: 1.0000 - val_loss: 0.4772 - val_accuracy: 0.9393 - val_top-5-accuracy: 1.0000
# Epoch 35/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4496 - accuracy: 0.9488 - top-5-accuracy: 1.0000 - val_loss: 0.5003 - val_accuracy: 0.9327 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4421 - accuracy: 0.9532 - top-5-accuracy: 1.0000 - val_loss: 0.4711 - val_accuracy: 0.9379 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4413 - accuracy: 0.9540 - top-5-accuracy: 1.0000 - val_loss: 0.4795 - val_accuracy: 0.9410 - val_top-5-accuracy: 1.0000
# Epoch 38/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4410 - accuracy: 0.9541 - top-5-accuracy: 1.0000 - val_loss: 0.4801 - val_accuracy: 0.9362 - val_top-5-accuracy: 1.0000
# Epoch 39/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4392 - accuracy: 0.9542 - top-5-accuracy: 1.0000 - val_loss: 0.4796 - val_accuracy: 0.9343 - val_top-5-accuracy: 1.0000
# Epoch 40/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4389 - accuracy: 0.9539 - top-5-accuracy: 1.0000 - val_loss: 0.4929 - val_accuracy: 0.9341 - val_top-5-accuracy: 1.0000
# Epoch 41/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4381 - accuracy: 0.9560 - top-5-accuracy: 1.0000 - val_loss: 0.4649 - val_accuracy: 0.9459 - val_top-5-accuracy: 1.0000
# Epoch 42/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4358 - accuracy: 0.9566 - top-5-accuracy: 1.0000 - val_loss: 0.4675 - val_accuracy: 0.9429 - val_top-5-accuracy: 1.0000
# Epoch 43/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4340 - accuracy: 0.9568 - top-5-accuracy: 1.0000 - val_loss: 0.4783 - val_accuracy: 0.9419 - val_top-5-accuracy: 1.0000
# Epoch 44/100
# 297/297 [==============================] - 11s 35ms/step - loss: 0.4323 - accuracy: 0.9590 - top-5-accuracy: 1.0000 - val_loss: 0.4778 - val_accuracy: 0.9417 - val_top-5-accuracy: 1.0000
# Epoch 45/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4275 - accuracy: 0.9613 - top-5-accuracy: 1.0000 - val_loss: 0.4740 - val_accuracy: 0.9393 - val_top-5-accuracy: 1.0000
# Epoch 46/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4262 - accuracy: 0.9616 - top-5-accuracy: 1.0000 - val_loss: 0.4786 - val_accuracy: 0.9414 - val_top-5-accuracy: 1.0000
# Epoch 47/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4292 - accuracy: 0.9598 - top-5-accuracy: 1.0000 - val_loss: 0.4894 - val_accuracy: 0.9324 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4262 - accuracy: 0.9615 - top-5-accuracy: 1.0000 - val_loss: 0.4869 - val_accuracy: 0.9393 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4310 - accuracy: 0.9585 - top-5-accuracy: 1.0000 - val_loss: 0.4756 - val_accuracy: 0.9391 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4249 - accuracy: 0.9621 - top-5-accuracy: 1.0000 - val_loss: 0.4704 - val_accuracy: 0.9417 - val_top-5-accuracy: 1.0000
# Epoch 51/100
# 297/297 [==============================] - 11s 35ms/step - loss: 0.4256 - accuracy: 0.9613 - top-5-accuracy: 1.0000 - val_loss: 0.4700 - val_accuracy: 0.9464 - val_top-5-accuracy: 1.0000
# Epoch 52/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4229 - accuracy: 0.9639 - top-5-accuracy: 1.0000 - val_loss: 0.4734 - val_accuracy: 0.9426 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 297/297 [==============================] - 11s 35ms/step - loss: 0.4214 - accuracy: 0.9639 - top-5-accuracy: 1.0000 - val_loss: 0.4645 - val_accuracy: 0.9474 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4193 - accuracy: 0.9657 - top-5-accuracy: 1.0000 - val_loss: 0.4647 - val_accuracy: 0.9467 - val_top-5-accuracy: 1.0000
# Epoch 55/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4172 - accuracy: 0.9669 - top-5-accuracy: 1.0000 - val_loss: 0.4713 - val_accuracy: 0.9462 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 297/297 [==============================] - 11s 35ms/step - loss: 0.4206 - accuracy: 0.9643 - top-5-accuracy: 1.0000 - val_loss: 0.4608 - val_accuracy: 0.9483 - val_top-5-accuracy: 1.0000
# Epoch 57/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4145 - accuracy: 0.9679 - top-5-accuracy: 1.0000 - val_loss: 0.4623 - val_accuracy: 0.9467 - val_top-5-accuracy: 1.0000
# Epoch 58/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4168 - accuracy: 0.9664 - top-5-accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 0.9443 - val_top-5-accuracy: 1.0000
# Epoch 59/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4179 - accuracy: 0.9657 - top-5-accuracy: 1.0000 - val_loss: 0.4813 - val_accuracy: 0.9417 - val_top-5-accuracy: 1.0000
# Epoch 60/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4156 - accuracy: 0.9673 - top-5-accuracy: 1.0000 - val_loss: 0.4829 - val_accuracy: 0.9379 - val_top-5-accuracy: 1.0000
# Epoch 61/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4150 - accuracy: 0.9667 - top-5-accuracy: 1.0000 - val_loss: 0.4755 - val_accuracy: 0.9414 - val_top-5-accuracy: 1.0000
# Epoch 62/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4111 - accuracy: 0.9699 - top-5-accuracy: 1.0000 - val_loss: 0.4629 - val_accuracy: 0.9483 - val_top-5-accuracy: 1.0000
# Epoch 63/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4123 - accuracy: 0.9697 - top-5-accuracy: 1.0000 - val_loss: 0.4798 - val_accuracy: 0.9405 - val_top-5-accuracy: 1.0000
# Epoch 64/100
# 297/297 [==============================] - 11s 36ms/step - loss: 0.4124 - accuracy: 0.9689 - top-5-accuracy: 1.0000 - val_loss: 0.4650 - val_accuracy: 0.9486 - val_top-5-accuracy: 1.0000
# Epoch 65/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4101 - accuracy: 0.9704 - top-5-accuracy: 1.0000 - val_loss: 0.4677 - val_accuracy: 0.9469 - val_top-5-accuracy: 1.0000
# Epoch 66/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4099 - accuracy: 0.9703 - top-5-accuracy: 1.0000 - val_loss: 0.4749 - val_accuracy: 0.9424 - val_top-5-accuracy: 1.0000
# Epoch 67/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4069 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.4580 - val_accuracy: 0.9514 - val_top-5-accuracy: 1.0000
# Epoch 68/100
# 297/297 [==============================] - 11s 36ms/step - loss: 0.4085 - accuracy: 0.9713 - top-5-accuracy: 1.0000 - val_loss: 0.4731 - val_accuracy: 0.9476 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4079 - accuracy: 0.9714 - top-5-accuracy: 1.0000 - val_loss: 0.4708 - val_accuracy: 0.9459 - val_top-5-accuracy: 1.0000
# Epoch 70/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.4062 - accuracy: 0.9724 - top-5-accuracy: 1.0000 - val_loss: 0.4652 - val_accuracy: 0.9495 - val_top-5-accuracy: 1.0000
# Epoch 71/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4065 - accuracy: 0.9719 - top-5-accuracy: 1.0000 - val_loss: 0.4753 - val_accuracy: 0.9462 - val_top-5-accuracy: 1.0000
# Epoch 72/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4057 - accuracy: 0.9723 - top-5-accuracy: 1.0000 - val_loss: 0.4651 - val_accuracy: 0.9469 - val_top-5-accuracy: 1.0000
# Epoch 73/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4009 - accuracy: 0.9753 - top-5-accuracy: 1.0000 - val_loss: 0.4735 - val_accuracy: 0.9436 - val_top-5-accuracy: 1.0000
# Epoch 74/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4045 - accuracy: 0.9738 - top-5-accuracy: 1.0000 - val_loss: 0.4718 - val_accuracy: 0.9474 - val_top-5-accuracy: 1.0000
# Epoch 75/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4016 - accuracy: 0.9747 - top-5-accuracy: 1.0000 - val_loss: 0.4655 - val_accuracy: 0.9486 - val_top-5-accuracy: 1.0000
# Epoch 76/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4011 - accuracy: 0.9753 - top-5-accuracy: 1.0000 - val_loss: 0.4583 - val_accuracy: 0.9514 - val_top-5-accuracy: 1.0000
# Epoch 77/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4016 - accuracy: 0.9744 - top-5-accuracy: 1.0000 - val_loss: 0.4680 - val_accuracy: 0.9495 - val_top-5-accuracy: 1.0000
# Epoch 78/100
# 297/297 [==============================] - 10s 35ms/step - loss: 0.3975 - accuracy: 0.9770 - top-5-accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.9526 - val_top-5-accuracy: 1.0000
# Epoch 79/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3999 - accuracy: 0.9763 - top-5-accuracy: 1.0000 - val_loss: 0.4608 - val_accuracy: 0.9493 - val_top-5-accuracy: 1.0000
# Epoch 80/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3951 - accuracy: 0.9785 - top-5-accuracy: 1.0000 - val_loss: 0.4919 - val_accuracy: 0.9407 - val_top-5-accuracy: 1.0000
# Epoch 81/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.4014 - accuracy: 0.9744 - top-5-accuracy: 1.0000 - val_loss: 0.4657 - val_accuracy: 0.9490 - val_top-5-accuracy: 1.0000
# Epoch 82/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3942 - accuracy: 0.9790 - top-5-accuracy: 1.0000 - val_loss: 0.4692 - val_accuracy: 0.9507 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3933 - accuracy: 0.9794 - top-5-accuracy: 1.0000 - val_loss: 0.4632 - val_accuracy: 0.9493 - val_top-5-accuracy: 1.0000
# Epoch 84/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3978 - accuracy: 0.9773 - top-5-accuracy: 1.0000 - val_loss: 0.4791 - val_accuracy: 0.9471 - val_top-5-accuracy: 1.0000
# Epoch 85/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3971 - accuracy: 0.9770 - top-5-accuracy: 1.0000 - val_loss: 0.4570 - val_accuracy: 0.9509 - val_top-5-accuracy: 1.0000
# Epoch 86/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3958 - accuracy: 0.9781 - top-5-accuracy: 1.0000 - val_loss: 0.4818 - val_accuracy: 0.9450 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3927 - accuracy: 0.9802 - top-5-accuracy: 1.0000 - val_loss: 0.4868 - val_accuracy: 0.9407 - val_top-5-accuracy: 1.0000
# Epoch 88/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3892 - accuracy: 0.9825 - top-5-accuracy: 1.0000 - val_loss: 0.4758 - val_accuracy: 0.9467 - val_top-5-accuracy: 1.0000
# Epoch 89/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3905 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.4689 - val_accuracy: 0.9497 - val_top-5-accuracy: 1.0000
# Epoch 90/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3899 - accuracy: 0.9817 - top-5-accuracy: 1.0000 - val_loss: 0.4763 - val_accuracy: 0.9448 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3902 - accuracy: 0.9809 - top-5-accuracy: 1.0000 - val_loss: 0.4879 - val_accuracy: 0.9346 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3913 - accuracy: 0.9810 - top-5-accuracy: 1.0000 - val_loss: 0.4791 - val_accuracy: 0.9448 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3907 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.4717 - val_accuracy: 0.9478 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3901 - accuracy: 0.9812 - top-5-accuracy: 1.0000 - val_loss: 0.4719 - val_accuracy: 0.9483 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3876 - accuracy: 0.9818 - top-5-accuracy: 1.0000 - val_loss: 0.4665 - val_accuracy: 0.9495 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3888 - accuracy: 0.9814 - top-5-accuracy: 1.0000 - val_loss: 0.4669 - val_accuracy: 0.9502 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3856 - accuracy: 0.9837 - top-5-accuracy: 1.0000 - val_loss: 0.4701 - val_accuracy: 0.9493 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3866 - accuracy: 0.9830 - top-5-accuracy: 1.0000 - val_loss: 0.4788 - val_accuracy: 0.9488 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3904 - accuracy: 0.9810 - top-5-accuracy: 1.0000 - val_loss: 0.4693 - val_accuracy: 0.9505 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 297/297 [==============================] - 10s 34ms/step - loss: 0.3850 - accuracy: 0.9834 - top-5-accuracy: 1.0000 - val_loss: 0.4947 - val_accuracy: 0.9414 - val_top-5-accuracy: 1.0000
# 233/233 [==============================] - 2s 9ms/step - loss: 0.4524 - accuracy: 0.9537 - top-5-accuracy: 1.0000
# Test accuracy: 95.37%
# Test top 5 accuracy: 100.0%
# 233/233 [==============================] - 2s 8ms/step
#                  precision    recall  f1-score   support
#
#           COVID       0.96      0.97      0.96      1992
#    Lung_Opacity       0.94      0.93      0.94      2102
#          Normal       0.92      0.92      0.92      1529
# Viral Pneumonia       0.99      0.99      0.99      1821
#
#        accuracy                           0.95      7444
#       macro avg       0.95      0.95      0.95      7444
#    weighted avg       0.95      0.95      0.95      7444

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(history.history["accuracy"], label="train_accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()
